# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

# %%
from src.battleships import BattleshipsBoard, AttackResult, Direction
from src.policies import Policy_10x10, sample_action_get_log_prob
from src.losses import VanillaPolictGradientLoss
import matplotlib.pyplot as plt
import numpy as np
import torch
import tqdm

# %% [markdown]
# ### Simple vanilla policy gradient RL

# %%
NUM_PARALLEL_GAMES = 100
NUM_EPOCHS = 100
LEARNING_RATE = 1e-3
DEVICE = 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f'Using device: {DEVICE}')

# %%
policy = Policy_10x10().to(DEVICE)
optimizer = torch.optim.AdamW(policy.parameters(), lr=LEARNING_RATE)
loss = VanillaPolictGradientLoss()

# %%
for epoch in range(NUM_EPOCHS):
    # initialize multiple game boards
    boards = [BattleshipsBoard.random_board() for _ in range(NUM_PARALLEL_GAMES)]

    # do i need to store all masks ro just previous mask?
    masks = [None] * NUM_PARALLEL_GAMES
    states = [None] * NUM_PARALLEL_GAMES

    # loop until all games are finished
    not_finished = True
    while not_finished:
        not_finished = False
        for board in boards:
            if not board.is_finished():
                not_finished = True
                state, mask = board.get_mask_and_state()

    # Training loop code goes here
    pass
